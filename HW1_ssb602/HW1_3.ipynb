# %%
import os
import sys
import numpy as np

# %%
np.random.seed(seed=None)

# %%
ReprRand = np.random.randn(2,100)

# %%
ReprRand.shape
# Out:
# (2, 100)

# %%
ReprRandAll = np.zeros((50, 2, 100))

# %%
ReprRandAll[49] = np.random.randn(2,100)

# %%
sigma = 2
mu = 3.5

# %%
for i in range(50):
    ReprRandAll[i] = sigma * np.random.randn(2,100) + mu

# %%
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
 fig, ax = plt.subplots(figsize=(10,10))
for i in range(50):
    ax.scatter(ReprRandAll[i][0],ReprRandAll[i][1])

# %% [markdown]
# ### Figure 1: [Scatter Plot for all points in ReprRandAll]
